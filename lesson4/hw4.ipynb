# %%
#Написать функцию, вычисляющее значение функции при х = 1.79

from math import *

def fanction_y(x):
    y = (cos(exp(x)) + 2*log1p(x) + sqrt(exp(cos(x))+(sin(pi*x))**2) + sqrt(1/x) + cos(x**2))**sin(x)
    print(f"Результат вычисления составил: {y}")

x = 1.79
fanction_y(x)
# Out:
# Результат вычисления составил: 3.7230820101533424

# %%
"""

    Напишите функцию search_substr(subst, st), которая принимает 2 строки и
определяет, имеется ли подстрока subst в строке st. В случае нахождения
подстроки, возвращается фраза «Есть контакт!», а иначе «Мимо!». Должно
быть найдено совпадение независимо от регистра обеих строк.

"""

def search_substr(subst, st):
    if (st.lower()).find(subst.lower()) != -1:
        print("Есть контакт!")
    else:
        print("Мимо!")
    
st = "Могучий рейнджер"
subst = "Рейн"
search_substr(subst, st)
# Out:
# Есть контакт!

# %%
"""

    На основании строки определить 3 наиболее часто встречаемых символа в
ней. Пробелы нужно игнорировать (не учитывать при подсчете). Для простоты
подсчета количества вхождений символов удобно использовать Counter из
модуля collections.

"""

from collections import Counter

def find_top3_symbols(str):
    top3 = Counter(str.replace(" ", "")).most_common(3)
    print("Наиболее часто встречающиеся символы:")
    for symbol, cnt in top3:
        print(f"{symbol} - {cnt}")

str = "sd fgh usi jfsfde retewe wers sfw foih gy vu sfij w"
find_top3_symbols(str)
# Out:
# Наиболее часто встречающиеся символы:
# s - 6
# f - 6
# e - 5

# %%
"""

    Дана строка в виде случайной последовательности чисел от 0 до 9.
Требуется создать словарь, который в качестве ключей будет принимать данные
числа (т.е. ключи будут типом int), а в качестве значений – количество этих
чисел в имеющейся последовательности. Для построения словаря создайте 
функцию count_it(sequence), принимающую строку из цифр. Функция должна
возвратить словарь из 3-х самых часто встречаемых чисел.

"""

from collections import Counter

def count_it(sequence):
    dictionary = {int(value): sequence.count(value) for value in sequence}
    sort_dict = sorted(dictionary.items(), key=lambda value: value[1], reverse = True)
    return dict(sort_dict[:3])
    
str = "33111222228"
count_it(str)
# Out:
# {2: 5, 1: 3, 3: 2}

# %%
"""

    Шахматы. у вас есть стандартное поле 8*8, после введения координат
(a, b) нахождения вашей фигуры и фигуры соперника (с, d), необходимо 
получить ответ, угрожает ли вражеская фигура вам:
1) вражеская фигура ферзь
2) вражеская фигура конь

"""

import math

def input_coordinates(coordinate):
    for i in range(0, 2):
        while True:
            try:
                coordinate[i] = int(input(f"Введите значение {i+1} координаты: "))
                if 0 <= coordinate[i] <= 8:
                    break
                else:
                    print()
                    print("Неверное значение, разрешен ввод от 0 до 8. Повторите еще раз")
            except:
                print("Неверное значение, разрешен ввод от 0 до 8. Повторите еще раз")
            print()   
    print(coordinate)
    print()

def check_coordinates(coordinates_1, coordinates_2):
    while True:
        if coordinates_1 == coordinates_2:
            print("Неверные значения координат, исправте")
            print("Координаты вашей фигуры: ")
            input_coordinates(coordinates_1)
            print("Координаты вражеской фигуры: ")
            input_coordinates(coordinates_2)
        else:
            break

def result(coordinates_1, coordinates_2):
    difference = [0, 0]
    difference[0] = coordinates_1[0] - coordinates_2[0]
    difference[1] = coordinates_1[1] - coordinates_2[1]
    if math.fabs(difference[0]) + math.fabs(difference[1]) == 3:
        print("Вашей фигуре угрожает конь!")
    elif math.fabs(difference[0]) == math.fabs(difference[1]) or difference[0] == 0 or difference[1] == 0:
        print("Вашей фигуре угрожает ферзь!")
    else:
        print("Угрозы нет)")
        
my_positoin = [0, 0]
enemy_position = [0, 0]
print("Координаты вашей фигуры: ")
input_coordinates(my_positoin)
print("Координаты вражеской фигуры: ")
input_coordinates(enemy_position)

check_coordinates(my_positoin, enemy_position)   
result(my_positoin, enemy_position)
# Out:
# Координаты вашей фигуры:
# Введите значение 1 координаты: 4
# Введите значение 2 координаты: 2
# [4, 2]
#
# Координаты вражеской фигуры:
# Введите значение 1 координаты: 3
# Введите значение 2 координаты: 3
# [3, 3]
#
# Вашей фигуре угрожает ферзь!

# %%
"""

    Шахматы. у вас есть стандартное поле 8*8, после введения координат (a, b)
нахождения вашей фигуры конь и фигуры соперника (с, d). Необходимо определить,
угрожаете ли вы сопернику, с учетом того, что у вас есть ход. (проверить состояние
до и после хода, координаты хода рассчитывается автоматически, соперник стоит на
месте)

"""

import math

def input_coordinates(coordinate):
    for i in range(0, 2):
        while True:
            try:
                coordinate[i] = int(input(f"Введите значение {i+1} координаты: "))
                if 0 <= coordinate[i] <= 8:
                    break
                else:
                    print()
                    print("Неверное значение, разрешен ввод от 0 до 8. Повторите еще раз")
            except:
                print("Неверное значение, разрешен ввод от 0 до 8. Повторите еще раз")
            print()   
    print(coordinate)
    print()

def check_coordinates(coordinates_1, coordinates_2):
    while True:
        if coordinates_1 == coordinates_2:
            print("Неверные значения координат, исправте")
            print("Координаты вашей фигуры: ")
            input_coordinates(coordinates_1)
            print("Координаты вражеской фигуры: ")
            input_coordinates(coordinates_2)
        else:
            break

def difference(coordinates_1, coordinates_2):
    dif = [0, 0]
    dif[0] = coordinates_1[0] - coordinates_2[0]
    dif[1] = coordinates_1[1] - coordinates_2[1]
    if math.fabs(dif[0]) + math.fabs(dif[1]) == 3 :
        return 1
    else:
        return 0
            
def before_the_move(coordinates_1, coordinates_2):
    res = difference(coordinates_1, coordinates_2)
    if res == 1: 
        print("Вы угрожаете сопернику, но у вас есть еще ход")
    else:
        print("Вы не угрожаете сопернику, но у вас есть еще ход")

def check_0_8(new_coordinates_1):
    if 0 <= new_coordinates_1[0] <= 8 and 0 <= new_coordinates_1[1] <= 8:
        return 1
    else:
        return 0
        
def move(new_coordinates_1, coordinates_2):
    new_coordinates_1[0] = new_coordinates_1[0] + coordinates_2[0]
    new_coordinates_1[1] = new_coordinates_1[1] + coordinates_2[1]
    return new_coordinates_1

def after_the_move(coordinates_1, coordinates_2):
    new_coordinates_1 = coordinates_1
    C1 = tuple(coordinates_1)
   
    move_1 = [1, 2]
    move(new_coordinates_1, move_1)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]        
    else:
        new_coordinates_1[0] = C1[0]
        new_coordinates_1[1] = C1[1]
            
    move_2 =[1, -2]
    move(new_coordinates_1, move_2)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]
    else:
        new_coordinates_1[0] = C1[0]
        new_coordinates_1[1] = C1[1] 
        
    move_3 =[-1, 2]
    move(new_coordinates_1, move_3)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]
    else:
        new_coordinates_1[0] = C1[0]
        new_coordinates_1[1] = C1[1]
    
    move_4 = [-1, -2]
    move(new_coordinates_1, move_4)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]
    else:
        new_coordinates_1[0] = C1[0]
        new_coordinates_1[1] = C1[1]  
    
    move_5 =[2, 1]
    move(new_coordinates_1, move_5)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]
            
    move_6 =[2, -1]
    move(new_coordinates_1, move_6)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]
    else:
        new_coordinates_1[0] = C1[0]
        new_coordinates_1[1] = C1[1]
        
    move_7 =[-2, 1]
    move(new_coordinates_1, move_7)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]
    else:
        new_coordinates_1[0] = C1[0]
        new_coordinates_1[1] = C1[1]
        
    move_8 =[-2, -1]
    move(new_coordinates_1, move_8)
    move_check = check_0_8(new_coordinates_1)
    if move_check == 1:
        res = difference(new_coordinates_1, coordinates_2) 
        if res == 1:
            return "Вы угрожаете сопернику"
        else:
            new_coordinates_1[0] = C1[0]
            new_coordinates_1[1] = C1[1]
    else:
        new_coordinates_1[0] = C1[0]
        new_coordinates_1[1] = C1[1]       
    print("Даже после хода вы не представляете угрозы")    
    
my_positoin = [0, 0]
enemy_position = [0, 0]
print("Координаты вашей фигуры: ")
input_coordinates(my_positoin)
print("Координаты вражеской фигуры: ")
input_coordinates(enemy_position)

check_coordinates(my_positoin, enemy_position) 
before_the_move(my_positoin, enemy_position)
after_the_move(my_positoin, enemy_position)
# Out:
# Координаты вашей фигуры:
# Введите значение 1 координаты: 3
# Введите значение 2 координаты: 2
# [3, 2]
#
# Координаты вражеской фигуры:
# Введите значение 1 координаты: 1
# Введите значение 2 координаты: 6
# [1, 6]
#
# Вы не угрожаете сопернику, но у вас есть еще ход
# 'Вы угрожаете сопернику'
